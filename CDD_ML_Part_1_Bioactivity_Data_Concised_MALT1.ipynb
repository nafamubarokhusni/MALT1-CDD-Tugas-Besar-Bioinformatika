# %% [markdown]
# <a href="https://colab.research.google.com/github/nafamubarokhusni/MALT1-Classification-Tugas-Besar-Bioinformatika/blob/main/CDD_ML_Part_1_Bioactivity_Data_Concised_MALT1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 6.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for MALT1**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('mucosa-associated lymphoid tissue lymphoma translocation protein 1','Homo sapiens')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#      cross_references         organism  \
# 0                  []     Homo sapiens
# 1                  []     Homo sapiens
# 2                  []     Homo sapiens
# 3                  []     Homo sapiens
# 4                  []     Homo sapiens
# ...               ...              ...
# 9995               []      Felis catus
# 9996               []   Equus caballus
# 9997               []     Homo sapiens
# 9998               []     Mus musculus
# 9999               []  Monkeypox virus
#
#                                               pref_name  score  \
# 0     Mucosa-associated lymphoid tissue lymphoma tra...   78.0
# 1     Baculoviral IAP repeat-containing protein 3/Mu...   49.0
# 2              Neurogenic locus notch homolog protein 1   20.0
# 3                       Methylcytosine dioxygenase TET1   19.0
# 4                           ETS translocation variant 1   18.0
# ...                                                 ...    ...
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human MALT1* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human MALT1*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL3632452'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human MALT1* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 501  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 502  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 503  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 504  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 505  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id activity_properties assay_chembl_id  \
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('MALT1_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-16-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 501  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 502  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 503  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 504  {'action_type': 'INHIBITOR', 'description': 'N...             None
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 374

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 501  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 502  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 503  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 504  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 505  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id activity_properties assay_chembl_id  \
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL3632807    CC1(C)CCC2=C(O1)c1ccc([N+](=O)[O-])cc1C(=O)C2=O
# 1        CHEMBL3632806             CC1(C)CCC2=C(O1)c1ccc(C#N)cc1C(=O)C2=O
# 2        CHEMBL3632805              CC1(C)CCC2=C(O1)c1ccc(Br)cc1C(=O)C2=O
# 3        CHEMBL3632804               CC1(C)CCC2=C(O1)c1ccc(F)cc1C(=O)C2=O
# 4        CHEMBL3183233  COCCOc1nc(-c2ccc(Cl)c(Cl)c2)n(-c2ccc(NC(=O)CCl...
# ..                 ...                                                ...
# 501      CHEMBL5267101  N/C(=N\S(=O)(=O)c1ccncc1)NCc1cc(-c2ccc(Cl)cc2)...
# 502      CHEMBL5266044  N/C(=N\S(=O)(=O)c1cccs1)NCc1cc(-c2ccc(Cl)cc2)n...
# 503      CHEMBL5275402  Cn1ccc(S(=O)(=O)/N=C(\N)NCc2cc(-c3ccc(Cl)cc3)n...
# 504      CHEMBL5290312  N/C(=N\S(=O)(=O)c1cccc(F)c1)NCc1cc(-c2ccc(Cl)c...
# 505      CHEMBL5274033  COc1cccc(S(=O)(=O)/N=C(\N)NCc2cc(-c3ccc(Cl)cc3...
#
#     standard_value
# 0            400.0
# 1           1600.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('MALT1_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('MALT1_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL3632807    CC1(C)CCC2=C(O1)c1ccc([N+](=O)[O-])cc1C(=O)C2=O
# 1        CHEMBL3632806             CC1(C)CCC2=C(O1)c1ccc(C#N)cc1C(=O)C2=O
# 2        CHEMBL3632805              CC1(C)CCC2=C(O1)c1ccc(Br)cc1C(=O)C2=O
# 3        CHEMBL3632804               CC1(C)CCC2=C(O1)c1ccc(F)cc1C(=O)C2=O
# 4        CHEMBL3183233  COCCOc1nc(-c2ccc(Cl)c(Cl)c2)n(-c2ccc(NC(=O)CCl...
# ..                 ...                                                ...
# 369      CHEMBL5267101  N/C(=N\S(=O)(=O)c1ccncc1)NCc1cc(-c2ccc(Cl)cc2)...
# 370      CHEMBL5266044  N/C(=N\S(=O)(=O)c1cccs1)NCc1cc(-c2ccc(Cl)cc2)n...
# 371      CHEMBL5275402  Cn1ccc(S(=O)(=O)/N=C(\N)NCc2cc(-c3ccc(Cl)cc3)n...
# 372      CHEMBL5290312  N/C(=N\S(=O)(=O)c1cccc(F)c1)NCc1cc(-c2ccc(Cl)c...
# 373      CHEMBL5274033  COc1cccc(S(=O)(=O)/N=C(\N)NCc2cc(-c3ccc(Cl)cc3...
#
#      standard_value         class
# 0             400.0        active
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('MALT1_03_bioactivity_data_curated.csv', index=False)

# %%
! zip MALT1.zip *.csv
# Out:
#   adding: MALT1_01_bioactivity_data_raw.csv (deflated 93%)
#   adding: MALT1_02_bioactivity_data_preprocessed.csv (deflated 81%)
#   adding: MALT1_03_bioactivity_data_curated.csv (deflated 83%)

# %%
! ls -l
# Out:
# total 508
# -rw-r--r-- 1 root root 411143 Dec 11 05:31 MALT1_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  26973 Dec 11 05:32 MALT1_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  30553 Dec 11 05:32 MALT1_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  37888 Dec 11 05:32 MALT1.zip
# drwxr-xr-x 1 root root   4096 Dec  9 14:20 sample_data

# %% [markdown]
# ---
